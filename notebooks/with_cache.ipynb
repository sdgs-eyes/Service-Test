# %%
# %env DDS_CACHE_DISABLE=False
# %env DDSAPI_CLIENT_CACHE_DIR=/home/jovyan/pilot1/data/.cache
# Out:
# env: DDS_CACHE_DISABLE=False
# env: DDSAPI_CLIENT_CACHE_DIR=/home/jovyan/pilot1/data/.cache

# %%
import ddsapi

# %%
c = ddsapi.Client()

# %% [markdown]
# ### CMCC ERA5 downscaled @2km over Italy
#
# _dataset_id_: **era5-downscaled-over-italy**
#
# _products_: **hourly**, **orography**
#
# #### Available variables
# - water_evaporation_amount
# - surface_net_downward_shortwave_flux
# - surface_net_downward_longwave_flux
# - cloud_area_fraction
# - air_pressure_at_sea_level
# - specific_humidity
# - dew_point_temperature
# - max_air_temperature
# - min_air_temperature
# - precipitation_amount
# - air_temperature
# - grid_eastward_wind
# - grid_northward_wind
# - lwe_thickness_of_surface_snow_amount
# - lwe_thickness_of_moisture_content_of_soil_layer
#
# #### Temporal coverage & resolution
# 1980/01/01 - 2022/12/31 (hourly)
#
# #### Spatial coverage
# 34.8, 3.91, 48.59, 19.93

# %%
ds = c.retrieve("era5-downscaled-over-italy", "hourly",
{
    "area": { "north": 44.1, "south": 40.1,  "west": 11.5, "east": 13.5 },
    "time": { "start": "2020-01-03T12:00", "stop": "2020-01-05T12:00" },
    "variable": [ "air_temperature", "precipitation_amount" ],
    "format": "netcdf"
})

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                         (time: 49, rlat: 200, rlon: 77, bnds: 2)
# Coordinates:
#   * time                            (time) datetime64[ns] 2020-01-03T12:00:00...
#     height_2m                       float32 ...
#     crs_rotated_latitude_longitude  int64 ...
#     time_bnds                       (time, bnds) datetime64[ns] ...
#   * rlon                            (rlon) float64 -0.3732 -0.3532 ... 1.147
#     lon                             (rlat, rlon) float32 ...
#   * rlat                            (rlat) float64 -2.888 -2.868 ... 1.072 1.092
#     lat                             (rlat, rlon) float32 ...
# Dimensions without coordinates: bnds
# Data variables:
#     T_2M                            (time, rlat, rlon) float32 ...
#     TOT_PREC                        (time, rlat, rlon) float32 ...
# Attributes: (12/14)
#     CDI:             Climate Data Interface version 1.9.8 (https://mpimet.mpg...
#     Conventions:     CF-1.4
#     history:         Generated by CMCC DDS version 0.9.0 2023-11-22 12:16:04....
#     source:          COSMO
#     institution:     CMCC (Euro-Mediterranean Center on Climate Change), REMH...
#     title:           cclm-sp_2.4_terra_urb_2.3.1 simulation (0.02 Deg) forced...
#     ...              ...
#     conventionsURL:  http://www.cfconventions.org/
#     contact:         Mario Raffa (mario.raffa@cmcc.it)- Marianna Adinolfi (ma...
#     references:      http//www.clm-community.eu, http://www.cmcc.it
#     creation_date:   2022-10-22 00:28:52
#     grid_mapping:    rotated_pole
#     CDO:             Climate Data Operators version 1.9.8 (https://mpimet.mpg...

# %%
ds = c.retrieve("era5-downscaled-over-italy", "hourly",
{
    "time": { "year": [ "1999" ], "month": [ "7" ], "day": [ "12", "13", "14", "15", "16" ], "hour": [ "12" ] },
    "location": { "latitude": 42, "longitude": 16 },
    "variable": [ "air_temperature", "precipitation_amount" ],
    "format": "netcdf"
})

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (time: 5, points: 1, bnds: 2)
# Coordinates:
#     height_2m               float32 ...
#     lat                     (points) float32 ...
#     crs_latitude_longitude  int64 ...
#     lon                     (points) float32 ...
#   * time                    (time) datetime64[ns] 1999-07-12T12:00:00 ... 199...
#     time_bnds               (time, bnds) datetime64[ns] ...
# Dimensions without coordinates: points, bnds
# Data variables:
#     T_2M                    (time, points) float32 ...
#     TOT_PREC                (time, points) float32 ...
# Attributes: (12/14)
#     CDI:             Climate Data Interface version 1.9.8 (https://mpimet.mpg...
#     Conventions:     CF-1.4
#     history:         Generated by CMCC DDS version 0.9.0 2023-11-22 13:55:55....
#     source:          COSMO
#     institution:     CMCC (Euro-Mediterranean Center on Climate Change), REMH...
#     title:           cclm-sp_2.4_terra_urb_2.3.1 simulation (0.02 Deg) forced...
#     ...              ...
#     conventionsURL:  http://www.cfconventions.org/
#     contact:         Mario Raffa (mario.raffa@cmcc.it)- Marianna Adinolfi (ma...
#     references:      http//www.clm-community.eu, http://www.cmcc.it
#     creation_date:   2022-10-22 00:28:52
#     grid_mapping:    rotated_pole
#     CDO:             Climate Data Operators version 1.9.8 (https://mpimet.mpg...

# %%
ds.lat.values, ds.lon.values
# Out:
# (array([42.00192], dtype=float32), array([15.993209], dtype=float32))

# %% [markdown]
# ### CMEMS Atlantic-European North West Shelf-Ocean Biogeochemistry Reanalysis
#
# _dataset_id_: **nwshelf-biogeochemistry**
#
# _products_: **daily**, **monthly**
#
# #### Available variables
# - mass_concentration_of_chlorophyll_a_in_sea_water
#
# #### Temporal coverage & resolution
# - 2020/03/01 - 2020/03/31 (daily)
# - 2020 - 2022 (monthly)
#
# #### Spatial coverage
# 40.07, -19.89, 65, 13

# %% [markdown]
# ### Daily query

# %%
ds = c.retrieve("nwshelf-biogeochemistry", "daily",
{
    "variable": [
        "mass_concentration_of_chlorophyll_a_in_sea_water"
    ],
    "time": { 
        "start": "2020-03-03", 
        "stop": "2020-03-04",
    },
    "format": "netcdf"
})
# Out:
# 2023-11-22 13:56:04,355 INFO Sending request to https://ddshub-dev.cmcc.it/api/v2/datasets/nwshelf-biogeochemistry/daily/execute
# 2023-11-22 13:56:04,632 INFO Request is Submitted
# 2023-11-22 13:56:04,633 INFO Request is scheduled with ID: 315285
# 2023-11-22 13:56:04,677 INFO Request is in RUNNING state
# 2023-11-22 13:56:18,075 INFO Request is in DONE state
# 2023-11-22 13:56:18,119 INFO Downloading https://ddshub-dev.cmcc.it/api/v2/download/315285 to /tmp/tmprvshdxie (2.7M)
# 2023-11-22 13:56:18,510 INFO Download rate 6.9M/s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (time: 2, depth: 24, latitude: 375, longitude: 297)
# Coordinates:
#   * time                    (time) datetime64[ns] 2020-03-03T12:00:00 2020-03...
#   * longitude               (longitude) float32 -19.89 -19.78 ... 12.89 13.0
#   * depth                   (depth) float32 0.0 3.0 10.0 ... 3e+03 4e+03 5e+03
#   * latitude                (latitude) float32 40.07 40.13 40.2 ... 64.93 65.0
#     crs_latitude_longitude  int64 ...
# Data variables:
#     chl                     (time, depth, latitude, longitude) float32 ...
# Attributes: (12/13)
#     title:                daily-mean chlorophyll concentration (3D)
#     Conventions:          CF-1.7
#     references:           http://marine.copernicus.eu/
#     institution:          UK Met Office
#     netcdf-version-id:    netCDF-4
#     creation_date:        2020-08-08T00:00:00Z
#     ...                   ...
#     product:              NWSHELF_MULTIYEAR_BGC_004_011
#     credit:               E.U. Copernicus Marine Service Information (CMEMS)
#     forcing_data_source:  ECMWF; ERA5
#     licence:              http://marine.copernicus.eu/services-portfolio/serv...
#     history:              Generated by CMCC DDS version 0.9.0 2023-11-22 13:5...
#     contact:              servicedesk.cmems@mercator-ocean.eu

# %% [markdown]
# ### Monthly query

# %%
ds = c.retrieve("nwshelf-biogeochemistry", "monthly",
{
    "variable": [
        "mass_concentration_of_chlorophyll_a_in_sea_water"
    ],
    "time": { "year": ["2021"], "month": ["03", "05"] },
    "area": { "north": 55, "south": 45, "west": -5, "east": 8 },
    "vertical": [ 0 ],
    "format": "netcdf"
})
# Out:
# 2023-11-22 13:56:21,819 INFO Sending request to https://ddshub-dev.cmcc.it/api/v2/datasets/nwshelf-biogeochemistry/monthly/execute
# 2023-11-22 13:56:22,161 INFO Request is Submitted
# 2023-11-22 13:56:22,162 INFO Request is scheduled with ID: 315286
# 2023-11-22 13:56:22,206 INFO Request is in RUNNING state
# 2023-11-22 13:56:35,614 INFO Request is in DONE state
# 2023-11-22 13:56:35,663 INFO Downloading https://ddshub-dev.cmcc.it/api/v2/download/315286 to /tmp/tmpb9o9szv4 (77.1K)
# 2023-11-22 13:56:35,932 INFO Download rate 287K/s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (time: 2, depth: 1, latitude: 150, longitude: 117)
# Coordinates:
#   * time                    (time) datetime64[ns] 2021-03-16T12:00:00 2021-05...
#   * latitude                (latitude) float32 45.0 45.07 45.13 ... 54.87 54.93
#   * longitude               (longitude) float32 -4.889 -4.778 ... 7.889 8.0
#   * depth                   (depth) float32 0.0
#     crs_latitude_longitude  int64 ...
# Data variables:
#     chl                     (time, depth, latitude, longitude) float32 ...
# Attributes: (12/13)
#     Conventions:          CF-1.7
#     references:           http://marine.copernicus.eu/
#     institution:          UK Met Office
#     netcdf-version-id:    netCDF-4
#     creation_date:        2020-08-08T00:00:00Z
#     source:               AMM-FOAM 7 km (tidal) NEMO v3.6_FABM-ERSEM v15.06_N...
#     ...                   ...
#     credit:               E.U. Copernicus Marine Service Information (CMEMS)
#     forcing_data_source:  ECMWF; ERA5
#     licence:              http://marine.copernicus.eu/services-portfolio/serv...
#     title:                monthly-mean chlorophyll concentration (3D)
#     history:              Generated by CMCC DDS version 0.9.0 2023-11-22 13:5...
#     contact:              servicedesk.cmems@mercator-ocean.eu

# %% [markdown]
# ### Atlantic Ocean Colour (Copernicus-GlobColour), Bio-Geo-Chemical, L4 (daily interpolated) from Satellite Observations
#
# _dataset_id_: **oceancolor-biogeochemistry**
#
# _products_: **daily**, **monthly**
#
# #### Available variables
# - mass_concentration_of_chlorophyll_a_in_sea_water
# - CHL_uncertainty
# - status_flag
#
# #### Temporal coverage & resolution
# 2020/03/01 - 2020/03/31 (daily)
# 2020 - 2022 (monthly)
#
# #### Spatial coverage
# 40.07, -45.99, 66, 13

# %%
ds = c.retrieve("oceancolor-biogeochemistry", "daily",
{
    "variable": [ "mass_concentration_of_chlorophyll_a_in_sea_water" ],
    "time": { "year": [ "2020" ], "month": [ "3" ], "day": [ "3" ] },
    "format": "netcdf"
})
# Out:
# 2023-11-22 13:56:39,343 INFO Sending request to https://ddshub-dev.cmcc.it/api/v2/datasets/oceancolor-biogeochemistry/daily/execute
# 2023-11-22 13:56:39,559 INFO Request is Submitted
# 2023-11-22 13:56:39,560 INFO Request is scheduled with ID: 315287
# 2023-11-22 13:56:39,603 INFO Request is in RUNNING state
# 2023-11-22 13:56:53,018 INFO Request is in DONE state
# 2023-11-22 13:56:53,061 INFO Downloading https://ddshub-dev.cmcc.it/api/v2/download/315287 to /tmp/tmptrnspqtx (58.4M)
# 2023-11-22 13:56:55,985 INFO Download rate 20M/s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (time: 1, lat: 4416, lon: 5664)
# Coordinates:
#   * time                    (time) datetime64[ns] 2020-03-03
#   * lat                     (lat) float32 65.99 65.98 65.97 ... 20.02 20.01
#   * lon                     (lon) float32 -45.99 -45.98 -45.97 ... 12.98 12.99
#     crs_latitude_longitude  int64 ...
# Data variables:
#     CHL                     (time, lat, lon) float32 ...
# Attributes: (12/91)
#     lon_step:                        0.010416667
#     keywords:                        EARTH SCIENCE > OCEANS > OCEAN CHEMISTRY...
#     cmems_product_id:                OCEANCOLOUR_ATL_BGC_L4_MY_009_118
#     lat_step:                        0.010416667
#     grid_mapping:                    Equirectangular
#     title:                           cmems_obs-oc_atl_bgc-plankton_my_l4-gapf...
#     ...                              ...
#     westernmost_longitude:           -46.0
#     geospatial_vertical_positive:    up
#     date_created:                    2022-11-22T21:09:01Z
#     nb_valid_bins:                   18134247
#     pct_valid_bins:                  72.50153764815155
#     parameter:                       Chlorophyll-a concentration

# %% [markdown]
# ## SENTINEL 2 DATA

# %%
ds = c.retrieve("sentinel-2", "level-2A",
{
    "sensing_time": "2020-01-02",
    "resolution": ["R20m"],
    "band": [ "B03" ],
    "region": "Niger",
    "uuid": "587c5088-546b-4175-ac56-e6484c48f42e",
    "format": "netcdf"
})
# Out:
# 2023-11-22 13:57:12,698 INFO Sending request to https://ddshub-dev.cmcc.it/api/v2/datasets/sentinel-2/level-2A/execute
# 2023-11-22 13:57:12,790 INFO Request is Submitted
# 2023-11-22 13:57:12,791 INFO Request is scheduled with ID: 315288
# 2023-11-22 13:57:12,833 INFO Request is in RUNNING state
# 2023-11-22 14:00:04,317 INFO Request is in DONE state
# 2023-11-22 14:00:04,362 INFO Downloading https://ddshub-dev.cmcc.it/api/v2/download/315288 to /tmp/tmpjf2p7eg5 (517.5M)
# 2023-11-22 14:00:35,361 INFO Download rate 16.7M/s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (band: 1, y: 5490, x: 5490)
# Coordinates:
#   * band                     (band) int64 1
#   * x                        (x) float64 8e+05 8e+05 ... 9.098e+05 9.098e+05
#   * y                        (y) float64 1.6e+06 1.6e+06 ... 1.49e+06 1.49e+06
#     longitude                (y, x) float64 ...
#     crs_transverse_mercator  int64 ...
#     latitude                 (y, x) float64 ...
# Data variables:
#     R20m_B03                 (band, y, x) float64 ...

# %%
ds = c.retrieve("sentinel-2", "level-2A",
{
    "sensing_time": "2020-01-07",
    "resolution": ["R60m"],
    "band": "B03",
    "region": "Mali",
    "uuid": "82ee5a74-ee53-5858-b3cd-86d1c82f3d23",
    "format": "netcdf"
})
# Out:
# 2023-11-22 14:01:44,329 INFO Sending request to https://ddshub-dev.cmcc.it/api/v2/datasets/sentinel-2/level-2A/execute
# 2023-11-22 14:01:44,631 INFO Request is Submitted
# 2023-11-22 14:01:44,632 INFO Request is scheduled with ID: 315289
# 2023-11-22 14:01:44,678 INFO Request is in RUNNING state
# 2023-11-22 14:06:02,938 INFO Request is in DONE state
# 2023-11-22 14:06:02,983 INFO Downloading https://ddshub-dev.cmcc.it/api/v2/download/315289 to /tmp/tmpfnvvsu5h (57.5M)
# 2023-11-22 14:06:07,290 INFO Download rate 13.4M/s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (band: 1, y: 1830, x: 1830)
# Coordinates:
#   * x                        (x) float64 3e+05 3.001e+05 ... 4.097e+05 4.098e+05
#   * band                     (band) int64 1
#   * y                        (y) float64 1.7e+06 1.7e+06 ... 1.59e+06 1.59e+06
#     longitude                (y, x) float64 ...
#     crs_transverse_mercator  int64 ...
#     latitude                 (y, x) float64 ...
# Data variables:
#     R60m_B03                 (band, y, x) float64 ...
